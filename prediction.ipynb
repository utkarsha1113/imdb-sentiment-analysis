# %%
#step1: import all libraries and the load the model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
#load the imdb dataset word index
word_index=imdb.get_word_index()

# %%
reverse_word_index={value:key for key,value in word_index.items()}

# %%
#load the pretrained model with relu activation
model=load_model('SimpleRNN_project.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (32, 500, 128)         │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (32, 128)              │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313,027 (5.01 MB)
#  Trainable params: 1,313,025 (5.01 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.90688527, -0.7571036 , -0.718026  , ..., -0.822274  ,
#          -0.14611043,  0.81752   ],
#         [-0.03011078,  0.03358911,  0.01419468, ...,  0.0136022 ,
#           0.02855874,  0.03055315],
#         [-0.09134493,  0.0474516 ,  0.04374554, ...,  0.09353224,
#          -0.12414315,  0.0647709 ],
#         ...,
#         [ 0.01470153, -0.06411947,  0.02713283, ..., -0.0945654 ,
#          -0.0497387 ,  0.0667932 ],
#         [ 0.04586047, -0.0167677 , -0.0614503 , ...,  0.0273373 ,
#           0.09711289,  0.03598779],
#         [-0.16769245,  0.154566  ,  0.15457915, ...,  0.09298423,
#          -0.04291883, -0.23438215]], shape=(10000, 128), dtype=float32),
#  array([[-0.08504581,  0.0746333 , -0.09801655, ...,  0.18269618,
#          -0.07846947,  0.02241098],
#         [ 0.12079193,  0.14754158, -0.03985606, ...,  0.0784956 ,
#           0.02319816,  0.03784833],
#         [ 0.16224648,  0.04965359, -0.07126129, ..., -0.03587161,
# ...

# %%
#step 2:helper functions
#functions to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i-3,'?')for i in encoded_review])

# %%
#function to prerprocess user input
def preprocess_text(text):
    words=text.lower().split()
    encoded_review=[word_index.get(word,2)+3 for word in words]
    padded_review=sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
#step 3 
#prediction funnction
def prediction_sentiment(review):
    preprocessed_input=preprocess_text(review)
    prediction=model.predict(preprocessed_input)
    sentiment='positive' if prediction[0][0]> 0.5 else 'negative'
    return sentiment,prediction[0][0]

# %%
# step 4:user input AND PREDICTION 
#expample review for the prediction
example_review="this movie was fantastic!! i really loved it!!"
sentiment,score=prediction_sentiment(example_review)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step

# %%
print(f"Review :{example_review}")
print(f"sentiment:{sentiment}")
print(f"prediction score:{score}")
# Out:
# Review :this movie was fantastic!! i really loved it!!
# sentiment:positive
# prediction score:0.7873328328132629

# %%
# step 4:user input AND PREDICTION 
#expample review for the prediction
example_review="worst movie i ever seen"
sentiment,score=prediction_sentiment(example_review)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
print(f"Review :{example_review}")
print(f"sentiment:{sentiment}")
print(f"prediction score:{score}")
# Out:
# Review :worst movie i ever seen
# sentiment:negative
# prediction score:0.09041835367679596
